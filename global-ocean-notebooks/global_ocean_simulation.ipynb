# %% [markdown]
# # Realistic Ocean Simulations in pure Julia
#
# In this tutorial we will build a global ocean simulation using the ClimaOcean and Oceananigans Julia packages.
# The simulation will be at a nominal four-degree with parameterizations for mesoscale eddies and vertical mixing.
# We will set up the grid, download and interpolate the bathymetry,
# download forcing files, and finally set up and run the simulation

# %% [markdown]
# ## Required software
#
# The tutorial is quite computationally expensive, therefore, if you have
# access, it is recommended to run the tutorial on one GPU.
# However, for the purpose of understanding how the library works,
# a 2 degree global ocean model runs comfortably on a laptop.

# %% [markdown]
# ## Packages:

# %% [markdown]
# Let's start by importing the necessary packages, these are:
# - ClimaOcean: the ocean model
# - Oceananigans: the fluid dynamics library doing the heavy lifting
# - Printf: always useful for spitting out output
# - CairoMakie: visualization package to visualize the results

# %%
using Pkg
Pkg.activate("./")

using ClimaOcean
using Oceananigans
using Oceananigans.Units
using Oceananigans.Grids
using Dates
using Printf
using CairoMakie
# Out:
#   Activating project at `~/development/EGU2025-Julia-intro-and-showcase-for-geoscience/global-ocean-notebooks`
# ┌ Warning: Error requiring `IntervalArithmetic` from `TaylorSeries`
# │   exception =
# │    LoadError: UndefVarError: `IntervalBox` not defined
# │    Stacktrace:
# │      [1] top-level scope
# │        @ ~/.julia/packages/TaylorSeries/ZBRjU/src/intervals.jl:171
# │      [2] include(mod::Module, _path::String)
# │        @ Base ./Base.jl:495
# │      [3] include(x::String)
# │        @ TaylorSeries ~/.julia/packages/TaylorSeries/ZBRjU/src/TaylorSeries.jl:17
# │      [4] top-level scope
# │        @ ~/.julia/packages/Requires/1eCOK/src/Requires.jl:40
# │      [5] eval
# │        @ ./boot.jl:385 [inlined]
# │      [6] eval
# │        @ ~/.julia/packages/TaylorSeries/ZBRjU/src/TaylorSeries.jl:17 [inlined]
# │      [7] (::TaylorSeries.var"#54#57")()
# │        @ TaylorSeries ~/.julia/packages/Requires/1eCOK/src/require.jl:101
# │      [8] macro expansion
# │        @ timing.jl:395 [inlined]
# │      [9] err(f::Any, listener::Module, modname::String, file::String, line::Any)
# │        @ Requires ~/.julia/packages/Requires/1eCOK/src/require.jl:47
# │     [10] (::TaylorSeries.var"#53#56")()
# │        @ TaylorSeries ~/.julia/packages/Requires/1eCOK/src/require.jl:100
# │     [11] withpath(f::Any, path::String)
# │        @ Requires ~/.julia/packages/Requires/1eCOK/src/require.jl:37
# │     [12] (::TaylorSeries.var"#52#55")()
# │        @ TaylorSeries ~/.julia/packages/Requires/1eCOK/src/require.jl:99
# │     [13] #invokelatest#2
# │        @ ./essentials.jl:892 [inlined]
# │     [14] invokelatest
# │        @ ./essentials.jl:889 [inlined]
# │     [15] foreach(f::typeof(invokelatest), itr::Vector{Function})
# │        @ Base ./abstractarray.jl:3098
# │     [16] loadpkg(pkg::Base.PkgId)
# │        @ Requires ~/.julia/packages/Requires/1eCOK/src/require.jl:27
# │     [17] #invokelatest#2
# │        @ ./essentials.jl:892 [inlined]
# │     [18] invokelatest
# │        @ ./essentials.jl:889 [inlined]
# │     [19] run_package_callbacks(modkey::Base.PkgId)
# │        @ Base ./loading.jl:1229
# │     [20] _tryrequire_from_serialized(modkey::Base.PkgId, path::String, ocachepath::String, sourcepath::String, depmods::Vector{Any})
# │        @ Base ./loading.jl:1557
# │     [21] _require_search_from_serialized(pkg::Base.PkgId, sourcepath::String, build_id::UInt128)
# │        @ Base ./loading.jl:1644
# │     [22] _require(pkg::Base.PkgId, env::String)
# │        @ Base ./loading.jl:2008
# │     [23] __require_prelocked(uuidkey::Base.PkgId, env::String)
# │        @ Base ./loading.jl:1882
# │     [24] #invoke_in_world#3
# │        @ ./essentials.jl:926 [inlined]
# │     [25] invoke_in_world
# │        @ ./essentials.jl:923 [inlined]
# │     [26] _require_prelocked(uuidkey::Base.PkgId, env::String)
# │        @ Base ./loading.jl:1873
# │     [27] macro expansion
# │        @ ./loading.jl:1860 [inlined]
# │     [28] macro expansion
# │        @ ./lock.jl:267 [inlined]
# │     [29] __require(into::Module, mod::Symbol)
# │        @ Base ./loading.jl:1823
# │     [30] #invoke_in_world#3
# │        @ ./essentials.jl:926 [inlined]
# │     [31] invoke_in_world
# │        @ ./essentials.jl:923 [inlined]
# │     [32] require(into::Module, mod::Symbol)
# │        @ Base ./loading.jl:1816
# │     [33] eval
# │        @ ./boot.jl:385 [inlined]
# │     [34] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
# │        @ Base ./loading.jl:2146
# │     [35] softscope_include_string(m::Module, code::String, filename::String)
# │        @ SoftGlobalScope ~/.julia/packages/SoftGlobalScope/u4UzH/src/SoftGlobalScope.jl:65
# │     [36] execute_request(socket::ZMQ.Socket, msg::IJulia.Msg)
# │        @ IJulia ~/.julia/packages/IJulia/XF6bn/src/execute_request.jl:81
# │     [37] #invokelatest#2
# │        @ ./essentials.jl:892 [inlined]
# │     [38] invokelatest
# │        @ ./essentials.jl:889 [inlined]
# │     [39] eventloop(socket::ZMQ.Socket)
# │        @ IJulia ~/.julia/packages/IJulia/XF6bn/src/eventloop.jl:14
# │     [40] (::IJulia.var"#15#18")()
# │        @ IJulia ~/.julia/packages/IJulia/XF6bn/src/eventloop.jl:51
# │    in expression starting at /Users/simonesilvestri/.julia/packages/TaylorSeries/ZBRjU/src/intervals.jl:171
# └ @ Requires ~/.julia/packages/Requires/1eCOK/src/require.jl:51

# %% [markdown]
# # Building a Global Ocean domain

# %% [markdown]
# We will start building a global ocean in steps:
# - (1) specifying an **Architecture**
# - (2) choosing a **Vertical coordinate**
# - (2) Building a **Grid**
# - (3) Downloading an interpolating a **Bathymetry**

# %% [markdown]
# ### Architectures

# %% [markdown]
# using an architecture is easy...
# it is possible to choose between:
# - (1) CPU
# - (2) GPU
# - (3) Distributed

# %% [markdown]
# In this case, we select `CPU()`, which is always the right choice to start prototyping. Building the script on CPUs is better to catch potential bugs in the script.
# Once we know that everything works correctly, we can just change the following line to `arch = GPU()`, and voilá, the simulation runs on GPUs

# %%
arch = CPU()
# Out:
# CPU()

# %% [markdown]
# ### Vertical coordinates

# %% [markdown]
# Oceananigans currently supports only $z$ and $z^\star$ coordinates.
# ClimaOcean provides a simple utility to build a simple exponential vertical coordinate

# %%
depth   = 6000meters
Nz      = 10
r_faces = ClimaOcean.exponential_z_faces(; Nz, depth)
# Out:
# 11-element Vector{Float64}:
#  -6000.0
#  -3801.344048375254
#  -2399.4191178885567
#  -1505.5123157498406
#   -935.5321737800014
#   -572.0967893946568
#   -340.3601570150809
#   -192.59835644783735
#    -98.38127267184085
#    -38.30580769255842
#      0.0

# %% [markdown]
# To use z-star coordinates we need to use a `z_faces = MutableVerticalDiscetization(r_faces)`, as opposed to a to
# a `StaticVerticalDiscretization`, to set up the data structures required for a free-surface
# following vertical coordinate.

# %%
z_faces = MutableVerticalDiscretization(r_faces)
# Out:
# MutableVerticalDiscretization{Vector{Float64}, Vector{Float64}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing}([-6000.0, -3801.344048375254, -2399.4191178885567, -1505.5123157498406, -935.5321737800014, -572.0967893946568, -340.3601570150809, -192.59835644783735, -98.38127267184085, -38.30580769255842, 0.0], [-6000.0, -3801.344048375254, -2399.4191178885567, -1505.5123157498406, -935.5321737800014, -572.0967893946568, -340.3601570150809, -192.59835644783735, -98.38127267184085, -38.30580769255842, 0.0], nothing, nothing, nothing, nothing, nothing, nothing, nothing, nothing, nothing)

# %% [markdown]
# ## Building a grid

# %% [markdown]
# ClimaOcean allows building ocean simulations on three different grid types:
# - `RectilinearGrid`s which represent a _box_ or a Cartesian domain
# - `LatitudeLongitudeGrid`s, which discretizes the sphere along latitude and longitude lines
# - `OrthogonalSphericalShellGrid`s which discretize the sphere with two-dimensional coordinates that do not need to follow latitude and longitude lines.
#    The only constraint is that the grid must be locally orthogonal in the horizontal direction.
#
# `LatitudeLongitudeGrid`s are the easiest grids to work with since coordinates are one-dimensional and globally orthogonal.
# (i.e. latitude depends only on the `j`-index and longitude depends only on the `i`-index)
# However, `LatitudeLongitudeGrid`s have the problem of the zonal spacing approaching zero as we move to the poles.
#
# For this reason, to represent a global ocean we use a specific type of `OrthogonalSphericalShellGrid`,
# called `TripolarGrid` that discretizes the sphere as a set of perpendicular ellipses and hyperbolae.
#
# Let's build a coarse `TripolarGrid` (about 4 degree resolution).
# We pass to the grid, the architecture, the floating point precision, the size of the grid, and the vertical coordinate.

# %%
Nx   = 256 # longitudinal direction -> 256 points is about 1.5ᵒ resolution
Ny   = 128 # meridional direction -> same thing, 128 points is about 1.5ᵒ resolution
Nz   = length(r_faces) - 1
grid = TripolarGrid(arch, Float64; size=(Nx, Ny, Nz), z=z_faces)
# Out:
# 256×128×10 OrthogonalSphericalShellGrid{Float64, Periodic, RightConnected, Bounded} on CPU with 4×4×4 halo and with precomputed metrics
# ├── centered at (λ, φ) = (70.0, 1.8005)
# ├── longitude: Periodic  extent 360.153 degrees       variably spaced with min(Δλ)=0.014941, max(Δλ)=1.48183
# ├── latitude:  RightConnected  extent 171.328 degrees variably spaced with min(Δφ)=0.022547, max(Δφ)=1.33858
# └── z:         Bounded  z ∈ [-6000.0, 0.0]            variably spaced with min(Δr)=38.3058, max(Δr)=2198.66 (mutable)

# %% [markdown]
# #### Let's visualize the grid using CairoMakie

# %%
cartesian_nodes, _ = Oceananigans.Utils.get_cartesian_nodes_and_vertices(grid, Face(), Face(), Center())
xF, yF, zF = cartesian_nodes

cartesian_nodes, _ = Oceananigans.Utils.get_cartesian_nodes_and_vertices(grid, Center(), Center(), Center())
xC, yC, zC = cartesian_nodes

φ = Oceananigans.Grids.φnodes(grid, Center(), Center())
λ = Oceananigans.Grids.λnodes(grid, Center(), Center())

fig = Figure(size=(1200, 300))
axC = Axis(fig[1, 1])
[vlines!(axC, i, color = :green, linewidth=0.5) for i in 1:5:Nx]
[hlines!(axC, j, color = :green, linewidth=0.5) for j in 1:5:Ny]
contour!(axC, φ, levels=-80:10:90, color=:blue, linewidth=0.8)
contour!(axC, λ, levels=0:10:360,  color=:blue, linewidth=0.8)
xlims!(axC, 1, Nx-1)
ylims!(axC, 1, Ny-1)

display(fig)
# Out:
# CairoMakie.Screen{IMAGE}

# %% [markdown]
# ## Adding a bathymetry to the grid
#
# ClimaOcean provides a nifty utility to regrid the bathymetry over the grid, the `regrid_bathymetry` function.
# By default ClimaOcean downloads the ETOPO_2022 bathymetry at 1/60ᵒ resolution (459 MB) from the NOAA servers.
# !!! NOTE: This will download the ETOPO_2022 bathymetry, so make sure that you have an internet connection

# %%
bottom_height = regrid_bathymetry(grid; minimum_depth=15, major_basins=1)

grid = ImmersedBoundaryGrid(underlying_grid, GridFittedBottom(bottom_height); active_cells_map=true)
fig = Figure(size = (800, 400))
ax  = Axis(fig[1, 1])
heatmap!(ax, interior(grid.immersed_boundary.bottom_height, :, :, 1), colormap=:deep)
display(fig)
# Out:
# ┌ Info: Skipping passes for interpolating bathymetry of size (21600, 10800, 1)
# │ to target grid of size (256, 128, 10). Interpolation passes may only
# │ be used to coarsen bathymetry and require that the bathymetry
# └ is finer than the target grid in both horizontal directions.
# CairoMakie.Screen{IMAGE}

# %% [markdown]
# # Configuring an Ocean model
#
# ### Numerical details
#
# Oceananigans allows several numerical options.
# We use a WENO schemes for the advection of momentum and
# a centered scheme for tracer advection, to avoid implicit diapycnal diffusion of tracers.
# Stability in the momentum field is ensured by the WENO method. For the tracer field, since the centered
# scheme is dispersive, we need to add some explicit diffusion to avoid numerical instabilities.

# %%
# Centered(order = 2 - 12) (only even orders)
# UpwindBiased(order = 1 - 11) (only odd orders) 
# WENO(order = 3 - 11) (only odd orders, not higher than 9)
# VectorInvariant(scheme = EnergyConservingScheme() / EnstrophyConservingScheme())
# WENOVectorInvariant(vorticity_order, divergence_order, kinetic_energy_order, vertical_advection_order)

momentum_advection = WENOVectorInvariant(order=3)
tracer_advection   = Centered()

free_surface = SplitExplicitFreeSurface(grid; substeps=30)
# Out:
# SplitExplicitFreeSurface substepping with FixedSubstepNumber(21)

# %% [markdown]
# ### Physical parameterizations
#
# We add a GM parameterization for mesoscale eddies and a CATKE vertical mixing scheme.
# All the closures require passing also the desired floating point precision of the model

# %%
using Oceananigans.TurbulenceClosures: IsopycnalSkewSymmetricDiffusivity
using Oceananigans.TurbulenceClosures.TKEBasedVerticalDiffusivities: CATKEVerticalDiffusivity

eddy_closure = IsopycnalSkewSymmetricDiffusivity(κ_skew=1e3, κ_symmetric=1e3)
vertical_mixing = CATKEVerticalDiffusivity()

closure = (eddy_closure, vertical_mixing)
# Out:
# (IsopycnalSkewSymmetricDiffusivity: (κ_symmetric=1000.0, κ_skew=1000.0, (isopycnal_tensor=Oceananigans.TurbulenceClosures.SmallSlopeIsopycnalTensor{Float64}(0.0), slope_limiter=Oceananigans.TurbulenceClosures.FluxTapering{Float64}(0.01)), CATKEVerticalDiffusivity{VerticallyImplicitTimeDiscretization}
# ├── maximum_tracer_diffusivity: Inf
# ├── maximum_tke_diffusivity: Inf
# ├── maximum_viscosity: Inf
# ├── minimum_tke: 1.0e-9
# ├── negative_tke_time_scale: 60.0
# ├── minimum_convective_buoyancy_flux: 1.0e-11
# ├── tke_time_step: Nothing
# ├── mixing_length: TKEBasedVerticalDiffusivities.CATKEMixingLength
# │   ├── Cˢ:   1.131
# │   ├── Cᵇ:   0.28
# │   ├── Cʰⁱu: 0.242
# │   ├── Cʰⁱc: 0.098
# │   ├── Cʰⁱe: 0.548
# │   ├── Cˡᵒu: 0.361
# │   ├── Cˡᵒc: 0.369
# │   ├── Cˡᵒe: 7.863
# │   ├── Cᵘⁿu: 0.37
# │   ├── Cᵘⁿc: 0.572
# │   ├── Cᵘⁿe: 1.447
# │   ├── Cᶜu:  3.705
# │   ├── Cᶜc:  4.793
# │   ├── Cᶜe:  3.642
# │   ├── Cᵉc:  0.112
# │   ├── Cᵉe:  0.0
# │   ├── Cˢᵖ:  0.505
# │   ├── CRiᵟ: 1.02
# │   └── CRi⁰: 0.254
# └── turbulent_kinetic_energy_equation: TKEBasedVerticalDiffusivities.CATKEEquation
#     ├── CʰⁱD: 0.579
#     ├── CˡᵒD: 1.604
#     ├── CᵘⁿD: 0.923
#     ├── CᶜD:  3.254
#     ├── CᵉD:  0.0
#     ├── Cᵂu★: 3.179
#     ├── CᵂwΔ: 0.383
#     └── Cᵂϵ:  1.0)

# %% [markdown]
# ### Building the ocean simulation
#
# ClimaOcean provides a utility to build an ocean simulation with all the necessary components.
# The function `ocean_simulation` returns a `Simulation` object of a `HydrostaticFreeSurfaceModel` that has
# all the necessary components (BC, drag, etc) to run a global ocean simulation.

# %%
ocean = ocean_simulation(grid;
                         momentum_advection,
                         tracer_advection,
                         closure,
                         free_surface)

# %% [markdown]
# ### Initialize our Ocean
#
# We use ECCO climatology to initialize the temperature and salinity fields.
# We can use the metadata we defined earlier to set the initial conditions.
# We use ECCO climatology to initialize the temperature and salinity fields.
# We can use the metadata we defined earlier to set the initial conditions.
# To do this we need to be able to download ECCO data. This is done automatically by `ClimaOcean`
# provided that you have credentials to access the ECCO data. To do so, follow the instructions detailed in
# **https://github.com/CliMA/ClimaOcean.jl/blob/main/src/DataWrangling/ECCO/README.md**.
# If this is not possible I have prepared already inpainted files to use as initial conditions.
# They can be donwloaded by uncommenting the following lines:

# %%
# download("https://www.dropbox.com/scl/fi/rcvf3ryegvxlm8gnga87l/SALT_1993_01_inpainted.jld2?rlkey=ctz2ty1yh6yksse1izd7l7ltd&st=skmv636j&dl=0", "./SALT_1993_01_inpainted.jld2")
# download("https://www.dropbox.com/scl/fi/3m9sw2lk149zgat6p8nil/SALT_1993_01.nc?rlkey=j1bz8zttg5n5lb1dhi547b2vh&st=ootshgfb&dl=0", "./SALT_1993_01.nc")
# download("https://www.dropbox.com/scl/fi/kmucmk4wb5cd1ckez6ts7/THETA_1993_01_inpainted.jld2?rlkey=v04dxmkgnrve5ob0boe6b52jp&st=wpdksush&dl=0", "./THETA_1993_01_inpainted.jld2")
# download("https://www.dropbox.com/scl/fi/6yzx1fvfk5b6ygyhi4sin/THETA_1993_01.nc?rlkey=euca05m5deb4kl8ylmg5nkasx&st=b4ooh3rd&dl=0", "./THETA_1993_01.nc")

# %%
using ClimaOcean.ECCO

temperature = Metadatum(:temperature; dir="./", dataset=ECCO4Monthly())
salinity    = Metadatum(:salinity;    dir="./", dataset=ECCO4Monthly())

set!(ocean.model, T=temperature, S=salinity)

# %% [markdown]
# ### Visualizing the initial conditions
#
# Let's visualize the surface of our initialized ocean model

# %%
fig = Figure(size = (2000, 800))
axT = Axis(fig[1, 1])
axS = Axis(fig[1, 2])

hmT = heatmap!(axT, interior(ocean.model.tracers.T, :, :, grid.Nz), colorrange=(-1, 30), colormap=:magma)
hmS = heatmap!(axS, interior(ocean.model.tracers.S, :, :, grid.Nz), colorrange=(28, 38), colormap=:haline)
Colorbar(fig[0, 1], hmT, vertical=false, label="Surface temperature ᵒC")
Colorbar(fig[0, 2], hmS, vertical=false, label="Surface salinity psu")

display(fig)
# Out:
# CairoMakie.Screen{IMAGE}

# %% [markdown]
# # Adding an atmosphere
#
# ClimaOcean is a prototype for a coupled earth system model.
# It couples an atmosphere to an ocean and computes air-sea fluxes using bulk formulae.
# At the moment, ClimaOcean provides a utility to download the JRA55 atmospheric reanalysis
# and use it as a prescribed atmosphere.
#
# !!! NOTE: This will download the JRA55 atmospheric reanalysis, so make sure that you have an internet connection (and enough disk space)
#
# We use an idealized atmosphere for this tutorial to avoid downloading the JRA55 data (~15GB).

# %%
atmos_grid  = LatitudeLongitudeGrid(arch, Float32; size=(320, 200), latitude=(-90, 90), longitude=(0, 360), topology=(Periodic, Bounded, Flat))
atmos_times = range(0, 360Oceananigans.Units.days, length=10)
atmosphere  = PrescribedAtmosphere(atmos_grid, atmos_times)
# Out:
# 320×200×1×10 PrescribedAtmosphere{Float32} on LatitudeLongitudeGrid:
# ├── times: 10-element StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}
# ├── surface_layer_height: 10.0
# └── boundary_layer_height: 600.0

# %% [markdown]
# We set up the atmosphere with an idealized temperature and wind speed that do not change in time.

# %%
Tₐ(λ, φ) = 220 + cosd(φ)^2 * 80
uₐ(λ, φ) = 10 * sind(2φ)^2
qₐ(λ, φ) = cosd(φ) * 3e-2

for t in eachindex(atmos_times)
    set!(atmosphere.tracers.T[t],    Tₐ)
    set!(atmosphere.tracers.q[t],    qₐ)
    set!(atmosphere.velocities.u[t], uₐ)

    Oceananigans.BoundaryConditions.fill_halo_regions!(atmosphere.tracers.T[t])
    Oceananigans.BoundaryConditions.fill_halo_regions!(atmosphere.tracers.q[t])
    Oceananigans.BoundaryConditions.fill_halo_regions!(atmosphere.velocities.u[t])
end

# %% [markdown]
# To use the JRA55 atmosphere, comment the above lines and uncomment the following line:

# %%
atmosphere = JRA55PrescribedAtmosphere(arch; dir="./")
# Out:
# [ Info:  ... downloaded 17.0 B (100% complete, 3.265 days)
# [ Info:  ... downloaded 17.0 B (100% complete, 3.265 days)
# [ Info:  ... downloaded 17.0 B (100% complete, 3.265 days)
# [ Info:  ... downloaded 535.2 MiB (30% complete, 3.265 days)
# [ Info:  ... downloaded 713.6 MiB (40% complete, 3.265 days)
# [ Info:  ... downloaded 892.0 MiB (50% complete, 3.265 days)
# [ Info:  ... downloaded 1.0 GiB (60% complete, 3.265 days)
# [ Info:  ... downloaded 1.2 GiB (70% complete, 3.265 days)
# [ Info:  ... downloaded 1.4 GiB (80% complete, 3.265 days)
# [ Info:  ... downloaded 1.6 GiB (90% complete, 3.266 days)
# [ Info:  ... downloaded 1.7 GiB (100% complete, 3.266 days)

# %% [markdown]
# If we had a realistic atmosphere we would add radiative properties, however, since we do not have
# downwelling radiation, we set it to nothing. If using a `JRA55PrescribedAtmosphere`, uncomment the first line and comment the second

# %%
# radiation = Radiation(ocean_albedo = LatitudeDependentAlbedo())
radiation = Radiation(ocean_albedo=1, ocean_emissivity=0)
# Out:
# Radiation{Float64}:
# ├── stefan_boltzmann_constant: 5.67e-8
# ├── emission: SurfaceProperties
# │   ├── ocean: 0.0
# │   └── sea_ice: 0.0
# └── reflection: SurfaceProperties
#     ├── ocean: 1.0
#     └── sea_ice: 0.7

# %% [markdown]
# ### Coupling the atmosphere to the ocean
#
# The `OceanSeaIceModel` is an `AbstractModel` defined in ClimaOcean that couples an ocean to an atmosphere and a sea ice component.
# For the moment, the sea-ice component is not implemented, so we will only couple the ocean to the atmosphere.
# Instead of the sea ice model, we limit the temperature of the ocean to the freezing temperature.

# %%
earth_model = OceanSeaIceModel(ocean; atmosphere, radiation)
# Out:
# OceanSeaIceModel{CPU}(time = 0 seconds, iteration = 0)
# ├── ocean: HydrostaticFreeSurfaceModel{CPU, ImmersedBoundaryGrid}(time = 0 seconds, iteration = 0)
# ├── atmosphere: 320×200×1×10 PrescribedAtmosphere{Float32}
# ├── sea_ice: FreezingLimitedOceanTemperature{ClimaSeaIce.SeaIceThermodynamics.LinearLiquidus{Float64}}
# └── interface: ComponentInterfaces

# %% [markdown]
# ### Building the simulation
#
# We build the simulation out of the `earth_model` as we would do for any other Oceananigans model.
# We start with a smallish time-step (5 minutes) and run only for 2 days to dissipate initialization shocks.

# %%
earth = Simulation(earth_model; Δt=30minutes, stop_time=30days)
# Out:
# Simulation of OceanSeaIceModel{CPU}(time = 0 seconds, iteration = 0)
# ├── Next time step: 30 minutes
# ├── Elapsed wall time: 0 seconds
# ├── Wall time per iteration: NaN days
# ├── Stop time: 30 days
# ├── Stop iteration: Inf
# ├── Wall time limit: Inf
# ├── Minimum relative step: 0.0
# ├── Callbacks: OrderedDict with 4 entries:
# │   ├── stop_time_exceeded => Callback of stop_time_exceeded on IterationInterval(1)
# │   ├── stop_iteration_exceeded => Callback of stop_iteration_exceeded on IterationInterval(1)
# │   ├── wall_time_limit_exceeded => Callback of wall_time_limit_exceeded on IterationInterval(1)
# │   └── nan_checker => Callback of NaNChecker for u_ocean on IterationInterval(100)
# ├── Output writers: OrderedDict with no entries
# └── Diagnostics: OrderedDict with no entries

# %% [markdown]
# ### Adding some diagnostics
#
# We add a callback to save surface fields as well as surface fluxes, every 6 hours

# %%
u, v, _ = ocean.model.velocities
T = ocean.model.tracers.T
S = ocean.model.tracers.S
s = sqrt(u^2 + v^2)

η = ocean.model.free_surface.η

earth.output_writers[:surface_tracers] = JLD2OutputWriter(ocean.model, (; T, S, s),
                                                          schedule = TimeInterval(12hours),
                                                          indices = (:, :, grid.Nz),
                                                          overwrite_existing = true,
                                                          filename = "surface_fields.jld2")


earth.output_writers[:free_surface] = JLD2OutputWriter(ocean.model, (; η),
                                                       schedule = TimeInterval(12hours),
                                                       overwrite_existing = true,
                                                       filename = "free_surface.jld2")

Q  = earth.model.interfaces.net_fluxes.ocean_surface.Q
τx = earth.model.interfaces.net_fluxes.ocean_surface.u
τy = earth.model.interfaces.net_fluxes.ocean_surface.v
PE = earth.model.interfaces.net_fluxes.ocean_surface.S

earth.output_writers[:fluxes] = JLD2OutputWriter(ocean.model, (; Q, τx, τy, PE),
                                                 schedule = TimeInterval(12hours),
                                                 overwrite_existing = true,
                                                 filename = "surface_fluxes.jld2")
# Out:
# JLD2OutputWriter scheduled on TimeInterval(12 hours):
# ├── filepath: surface_fluxes.jld2
# ├── 4 outputs: (Q, τx, τy, PE)
# ├── array type: Array{Float32}
# ├── including: [:grid, :coriolis, :buoyancy, :closure]
# ├── file_splitting: NoFileSplitting
# └── file size: 54.3 MiB

# %% [markdown]
# Also, we add a callback to print a message about how the simulation is going

# %%
wall_time = [time_ns()]

function progress(earth)
    clock   = earth.model.clock

    maxu = maximum(abs, u)
    maxv = maximum(abs, v)
    maxT = maximum(T)
    minS = minimum(S)

    @info @sprintf("Iteration: %d, time: %s, wall_time: %s, max(|u|, |v|): %.2e %.2e max(T): %.2e, min(S): %.2e\n",
                   clock.iteration, prettytime(clock.time), prettytime(1e-9 * (time_ns() - wall_time[1])), maxu, maxv, maxT, minS)

    wall_time[1] = time_ns()
end

add_callback!(earth, progress, IterationInterval(10))

# %% [markdown]
# ### Running the simulation
#
# quite simply

# %%
run!(earth)
# Out:
# [ Info: Initializing simulation...
# [ Info: Iteration: 0, time: 0 seconds, wall_time: 16.698 seconds, max(|u|, |v|): 0.00e+00 0.00e+00 max(T): 3.09e+01, min(S): 2.79e+01
# [ Info:     ... simulation initialization complete (22.776 seconds)
# [ Info: Executing initial time step...
# [ Info:     ... initial time step complete (14.165 seconds).
# [ Info: Iteration: 10, time: 5 hours, wall_time: 24.838 seconds, max(|u|, |v|): 8.05e-01 9.87e-01 max(T): 3.09e+01, min(S): 2.79e+01
# [ Info: Iteration: 20, time: 10 hours, wall_time: 3.845 seconds, max(|u|, |v|): 1.09e+00 1.49e+00 max(T): 3.09e+01, min(S): 2.79e+01
# [ Info: Iteration: 30, time: 15 hours, wall_time: 3.673 seconds, max(|u|, |v|): 9.97e-01 1.88e+00 max(T): 3.09e+01, min(S): 2.79e+01
# [ Info: Iteration: 40, time: 20 hours, wall_time: 3.677 seconds, max(|u|, |v|): 9.34e-01 1.93e+00 max(T): 3.08e+01, min(S): 2.79e+01
# [ Info: Iteration: 50, time: 1.042 days, wall_time: 3.645 seconds, max(|u|, |v|): 1.01e+00 1.74e+00 max(T): 3.08e+01, min(S): 2.79e+01
# [ Info: Iteration: 60, time: 1.250 days, wall_time: 3.609 seconds, max(|u|, |v|): 1.09e+00 1.46e+00 max(T): 3.08e+01, min(S): 2.79e+01
# [ Info: Iteration: 70, time: 1.458 days, wall_time: 3.650 seconds, max(|u|, |v|): 1.11e+00 1.67e+00 max(T): 3.08e+01, min(S): 2.79e+01
# [ Info: Iteration: 80, time: 1.667 days, wall_time: 3.642 seconds, max(|u|, |v|): 1.07e+00 1.49e+00 max(T): 3.09e+01, min(S): 2.79e+01
# [ Info: Iteration: 90, time: 1.875 days, wall_time: 3.616 seconds, max(|u|, |v|): 1.10e+00 1.18e+00 max(T): 3.08e+01, min(S): 2.79e+01
# [ Info: Iteration: 100, time: 2.083 days, wall_time: 3.657 seconds, max(|u|, |v|): 1.49e+00 1.56e+00 max(T): 3.08e+01, min(S): 2.79e+01
# [ Info: Iteration: 110, time: 2.292 days, wall_time: 3.632 seconds, max(|u|, |v|): 1.76e+00 2.48e+00 max(T): 3.08e+01, min(S): 2.79e+01
# [ Info: Iteration: 120, time: 2.500 days, wall_time: 3.665 seconds, max(|u|, |v|): 1.82e+00 2.43e+00 max(T): 3.08e+01, min(S): 2.79e+01
# [ Info: Iteration: 130, time: 2.708 days, wall_time: 3.722 seconds, max(|u|, |v|): 2.08e+00 3.22e+00 max(T): 3.08e+01, min(S): 2.79e+01
# [ Info: Iteration: 140, time: 2.917 days, wall_time: 3.553 seconds, max(|u|, |v|): 2.15e+00 3.22e+00 max(T): 3.08e+01, min(S): 2.79e+01
# [ Info: Iteration: 150, time: 3.125 days, wall_time: 3.626 seconds, max(|u|, |v|): 2.26e+00 3.48e+00 max(T): 3.08e+01, min(S): 2.79e+01
# [ Info: Iteration: 160, time: 3.333 days, wall_time: 3.602 seconds, max(|u|, |v|): 2.03e+00 3.66e+00 max(T): 3.08e+01, min(S): 2.79e+01
# [ Info: Iteration: 170, time: 3.542 days, wall_time: 3.654 seconds, max(|u|, |v|): 2.12e+00 3.21e+00 max(T): 3.08e+01, min(S): 2.79e+01
# [ Info: Iteration: 180, time: 3.750 days, wall_time: 3.605 seconds, max(|u|, |v|): 1.48e+00 3.60e+00 max(T): 3.08e+01, min(S): 2.79e+01
# [ Info: Iteration: 190, time: 3.958 days, wall_time: 3.656 seconds, max(|u|, |v|): 1.77e+00 2.65e+00 max(T): 3.07e+01, min(S): 2.79e+01
# [ Info: Iteration: 200, time: 4.167 days, wall_time: 3.646 seconds, max(|u|, |v|): 1.12e+00 3.06e+00 max(T): 3.08e+01, min(S): 2.79e+01
# [ Info: Iteration: 210, time: 4.375 days, wall_time: 3.655 seconds, max(|u|, |v|): 1.32e+00 1.93e+00 max(T): 3.07e+01, min(S): 2.79e+01
# [ Info: Iteration: 220, time: 4.583 days, wall_time: 3.625 seconds, max(|u|, |v|): 9.73e-01 2.59e+00 max(T): 3.08e+01, min(S): 2.79e+01
# [ Info: Iteration: 230, time: 4.792 days, wall_time: 3.612 seconds, max(|u|, |v|): 1.03e+00 1.70e+00 max(T): 3.08e+01, min(S): 2.79e+01
# [ Info: Iteration: 240, time: 5 days, wall_time: 3.668 seconds, max(|u|, |v|): 1.10e+00 2.13e+00 max(T): 3.08e+01, min(S): 2.80e+01
# [ Info: Iteration: 250, time: 5.208 days, wall_time: 3.638 seconds, max(|u|, |v|): 1.38e+00 1.23e+00 max(T): 3.08e+01, min(S): 2.79e+01
# [ Info: Iteration: 260, time: 5.417 days, wall_time: 3.729 seconds, max(|u|, |v|): 1.74e+00 1.67e+00 max(T): 3.08e+01, min(S): 2.79e+01
# [ Info: Iteration: 270, time: 5.625 days, wall_time: 3.706 seconds, max(|u|, |v|): 1.57e+00 1.36e+00 max(T): 3.09e+01, min(S): 2.80e+01
# [ Info: Iteration: 280, time: 5.833 days, wall_time: 3.713 seconds, max(|u|, |v|): 2.15e+00 2.21e+00 max(T): 3.11e+01, min(S): 2.80e+01
# [ Info: Iteration: 290, time: 6.042 days, wall_time: 3.683 seconds, max(|u|, |v|): 1.77e+00 1.97e+00 max(T): 3.12e+01, min(S): 2.80e+01
# [ Info: Iteration: 300, time: 6.250 days, wall_time: 3.664 seconds, max(|u|, |v|): 2.50e+00 3.60e+00 max(T): 3.12e+01, min(S): 2.80e+01
# [ Info: Iteration: 310, time: 6.458 days, wall_time: 3.632 seconds, max(|u|, |v|): 2.43e+00 3.01e+00 max(T): 3.13e+01, min(S): 2.80e+01
# [ Info: Iteration: 320, time: 6.667 days, wall_time: 3.649 seconds, max(|u|, |v|): 2.79e+00 4.37e+00 max(T): 3.13e+01, min(S): 2.80e+01
# [ Info: Iteration: 330, time: 6.875 days, wall_time: 3.666 seconds, max(|u|, |v|): 2.79e+00 3.74e+00 max(T): 3.10e+01, min(S): 2.80e+01
# [ Info: Iteration: 340, time: 7.083 days, wall_time: 3.969 seconds, max(|u|, |v|): 2.90e+00 4.46e+00 max(T): 3.08e+01, min(S): 2.80e+01
# [ Info: Iteration: 350, time: 7.292 days, wall_time: 3.776 seconds, max(|u|, |v|): 2.74e+00 4.09e+00 max(T): 3.07e+01, min(S): 2.80e+01
# [ Info: Iteration: 360, time: 7.500 days, wall_time: 3.593 seconds, max(|u|, |v|): 2.68e+00 4.12e+00 max(T): 3.07e+01, min(S): 2.80e+01
# [ Info: Iteration: 370, time: 7.708 days, wall_time: 3.597 seconds, max(|u|, |v|): 2.35e+00 4.23e+00 max(T): 3.07e+01, min(S): 2.80e+01
# [ Info: Iteration: 380, time: 7.917 days, wall_time: 3.628 seconds, max(|u|, |v|): 2.36e+00 3.68e+00 max(T): 3.06e+01, min(S): 2.80e+01
# [ Info: Iteration: 390, time: 8.125 days, wall_time: 3.654 seconds, max(|u|, |v|): 2.05e+00 4.01e+00 max(T): 3.06e+01, min(S): 2.80e+01
# [ Info: Iteration: 400, time: 8.333 days, wall_time: 3.657 seconds, max(|u|, |v|): 2.12e+00 2.96e+00 max(T): 3.06e+01, min(S): 2.80e+01
# [ Info: Iteration: 410, time: 8.542 days, wall_time: 3.748 seconds, max(|u|, |v|): 1.87e+00 3.52e+00 max(T): 3.07e+01, min(S): 2.80e+01
# [ Info: Iteration: 420, time: 8.750 days, wall_time: 3.575 seconds, max(|u|, |v|): 1.84e+00 2.19e+00 max(T): 3.06e+01, min(S): 2.80e+01
# [ Info: Iteration: 430, time: 8.958 days, wall_time: 3.611 seconds, max(|u|, |v|): 1.72e+00 2.91e+00 max(T): 3.06e+01, min(S): 2.80e+01
# [ Info: Iteration: 440, time: 9.167 days, wall_time: 3.666 seconds, max(|u|, |v|): 1.71e+00 2.77e+00 max(T): 3.06e+01, min(S): 2.80e+01
# [ Info: Iteration: 450, time: 9.375 days, wall_time: 3.805 seconds, max(|u|, |v|): 1.54e+00 2.56e+00 max(T): 3.06e+01, min(S): 2.80e+01
# [ Info: Iteration: 460, time: 9.583 days, wall_time: 3.735 seconds, max(|u|, |v|): 1.31e+00 2.08e+00 max(T): 3.06e+01, min(S): 2.80e+01
# [ Info: Iteration: 470, time: 9.792 days, wall_time: 3.632 seconds, max(|u|, |v|): 1.57e+00 1.99e+00 max(T): 3.06e+01, min(S): 2.80e+01
# [ Info: Iteration: 480, time: 10 days, wall_time: 3.747 seconds, max(|u|, |v|): 1.58e+00 1.95e+00 max(T): 3.06e+01, min(S): 2.80e+01
# [ Info: Iteration: 490, time: 10.208 days, wall_time: 3.644 seconds, max(|u|, |v|): 2.05e+00 1.73e+00 max(T): 3.06e+01, min(S): 2.80e+01
# [ Info: Iteration: 500, time: 10.417 days, wall_time: 3.640 seconds, max(|u|, |v|): 1.39e+00 2.12e+00 max(T): 3.06e+01, min(S): 2.80e+01
# [ Info: Iteration: 510, time: 10.625 days, wall_time: 3.628 seconds, max(|u|, |v|): 2.36e+00 2.65e+00 max(T): 3.06e+01, min(S): 2.80e+01
# [ Info: Iteration: 520, time: 10.833 days, wall_time: 3.574 seconds, max(|u|, |v|): 2.04e+00 3.03e+00 max(T): 3.06e+01, min(S): 2.80e+01
# [ Info: Iteration: 530, time: 11.042 days, wall_time: 3.536 seconds, max(|u|, |v|): 2.63e+00 3.64e+00 max(T): 3.06e+01, min(S): 2.80e+01
# [ Info: Iteration: 540, time: 11.250 days, wall_time: 3.532 seconds, max(|u|, |v|): 2.24e+00 2.77e+00 max(T): 3.06e+01, min(S): 2.80e+01
# [ Info: Iteration: 550, time: 11.458 days, wall_time: 3.564 seconds, max(|u|, |v|): 2.69e+00 4.14e+00 max(T): 3.07e+01, min(S): 2.80e+01
# [ Info: Iteration: 560, time: 11.667 days, wall_time: 3.571 seconds, max(|u|, |v|): 2.57e+00 3.36e+00 max(T): 3.08e+01, min(S): 2.80e+01
# [ Info: Iteration: 570, time: 11.875 days, wall_time: 3.537 seconds, max(|u|, |v|): 2.83e+00 4.26e+00 max(T): 3.09e+01, min(S): 2.80e+01
# [ Info: Iteration: 580, time: 12.083 days, wall_time: 3.764 seconds, max(|u|, |v|): 2.58e+00 3.70e+00 max(T): 3.09e+01, min(S): 2.80e+01
# [ Info: Iteration: 590, time: 12.292 days, wall_time: 3.580 seconds, max(|u|, |v|): 2.81e+00 4.04e+00 max(T): 3.08e+01, min(S): 2.80e+01
# [ Info: Iteration: 600, time: 12.500 days, wall_time: 3.642 seconds, max(|u|, |v|): 2.41e+00 3.96e+00 max(T): 3.08e+01, min(S): 2.80e+01
# [ Info: Iteration: 610, time: 12.708 days, wall_time: 3.793 seconds, max(|u|, |v|): 2.61e+00 3.75e+00 max(T): 3.09e+01, min(S): 2.80e+01
# [ Info: Iteration: 620, time: 12.917 days, wall_time: 3.604 seconds, max(|u|, |v|): 2.06e+00 4.08e+00 max(T): 3.08e+01, min(S): 2.80e+01
# [ Info: Iteration: 630, time: 13.125 days, wall_time: 3.831 seconds, max(|u|, |v|): 2.35e+00 3.58e+00 max(T): 3.06e+01, min(S): 2.80e+01
# [ Info: Iteration: 640, time: 13.333 days, wall_time: 3.844 seconds, max(|u|, |v|): 1.84e+00 3.86e+00 max(T): 3.05e+01, min(S): 2.80e+01
# [ Info: Iteration: 650, time: 13.542 days, wall_time: 3.686 seconds, max(|u|, |v|): 2.31e+00 2.79e+00 max(T): 3.05e+01, min(S): 2.80e+01
# [ Info: Iteration: 660, time: 13.750 days, wall_time: 3.690 seconds, max(|u|, |v|): 1.88e+00 3.38e+00 max(T): 3.05e+01, min(S): 2.80e+01
# [ Info: Iteration: 670, time: 13.958 days, wall_time: 3.670 seconds, max(|u|, |v|): 1.75e+00 3.52e+00 max(T): 3.05e+01, min(S): 2.80e+01
# [ Info: Iteration: 680, time: 14.167 days, wall_time: 3.619 seconds, max(|u|, |v|): 1.74e+00 3.05e+00 max(T): 3.05e+01, min(S): 2.80e+01
# [ Info: Iteration: 690, time: 14.375 days, wall_time: 3.587 seconds, max(|u|, |v|): 2.14e+00 2.46e+00 max(T): 3.05e+01, min(S): 2.80e+01
# [ Info: Iteration: 700, time: 14.583 days, wall_time: 3.600 seconds, max(|u|, |v|): 2.75e+00 3.16e+00 max(T): 3.05e+01, min(S): 2.80e+01
# [ Info: Iteration: 710, time: 14.792 days, wall_time: 3.582 seconds, max(|u|, |v|): 1.69e+00 2.98e+00 max(T): 3.05e+01, min(S): 2.80e+01
# [ Info: Iteration: 720, time: 15 days, wall_time: 3.535 seconds, max(|u|, |v|): 1.63e+00 3.47e+00 max(T): 3.05e+01, min(S): 2.80e+01
# [ Info: Iteration: 730, time: 15.208 days, wall_time: 3.559 seconds, max(|u|, |v|): 1.84e+00 2.60e+00 max(T): 3.05e+01, min(S): 2.80e+01
# [ Info: Iteration: 740, time: 15.417 days, wall_time: 3.554 seconds, max(|u|, |v|): 2.30e+00 2.24e+00 max(T): 3.04e+01, min(S): 2.81e+01
# [ Info: Iteration: 750, time: 15.625 days, wall_time: 3.561 seconds, max(|u|, |v|): 2.55e+00 2.69e+00 max(T): 3.04e+01, min(S): 2.80e+01
# [ Info: Iteration: 760, time: 15.833 days, wall_time: 3.631 seconds, max(|u|, |v|): 2.27e+00 4.00e+00 max(T): 3.04e+01, min(S): 2.80e+01
# [ Info: Iteration: 770, time: 16.042 days, wall_time: 3.810 seconds, max(|u|, |v|): 1.63e+00 3.68e+00 max(T): 3.04e+01, min(S): 2.81e+01
# [ Info: Iteration: 780, time: 16.250 days, wall_time: 3.591 seconds, max(|u|, |v|): 2.57e+00 3.04e+00 max(T): 3.04e+01, min(S): 2.80e+01
# [ Info: Iteration: 790, time: 16.458 days, wall_time: 3.586 seconds, max(|u|, |v|): 2.07e+00 3.34e+00 max(T): 3.04e+01, min(S): 2.81e+01
# [ Info: Iteration: 800, time: 16.667 days, wall_time: 3.589 seconds, max(|u|, |v|): 2.72e+00 4.32e+00 max(T): 3.04e+01, min(S): 2.80e+01
# [ Info: Iteration: 810, time: 16.875 days, wall_time: 3.515 seconds, max(|u|, |v|): 2.33e+00 4.35e+00 max(T): 3.04e+01, min(S): 2.80e+01
# [ Info: Iteration: 820, time: 17.083 days, wall_time: 3.631 seconds, max(|u|, |v|): 2.84e+00 4.20e+00 max(T): 3.04e+01, min(S): 2.81e+01
# [ Info: Iteration: 830, time: 17.292 days, wall_time: 3.720 seconds, max(|u|, |v|): 2.67e+00 3.36e+00 max(T): 3.04e+01, min(S): 2.80e+01
# [ Info: Iteration: 840, time: 17.500 days, wall_time: 3.693 seconds, max(|u|, |v|): 2.96e+00 4.36e+00 max(T): 3.04e+01, min(S): 2.81e+01
# [ Info: Iteration: 850, time: 17.708 days, wall_time: 3.651 seconds, max(|u|, |v|): 2.68e+00 4.10e+00 max(T): 3.04e+01, min(S): 2.81e+01
# [ Info: Iteration: 860, time: 17.917 days, wall_time: 3.540 seconds, max(|u|, |v|): 2.95e+00 4.24e+00 max(T): 3.04e+01, min(S): 2.80e+01
# [ Info: Iteration: 870, time: 18.125 days, wall_time: 3.583 seconds, max(|u|, |v|): 2.64e+00 3.97e+00 max(T): 3.04e+01, min(S): 2.81e+01
# [ Info: Iteration: 880, time: 18.333 days, wall_time: 3.537 seconds, max(|u|, |v|): 2.80e+00 4.07e+00 max(T): 3.04e+01, min(S): 2.80e+01
# [ Info: Iteration: 890, time: 18.542 days, wall_time: 3.548 seconds, max(|u|, |v|): 2.40e+00 4.11e+00 max(T): 3.04e+01, min(S): 2.81e+01
# [ Info: Iteration: 900, time: 18.750 days, wall_time: 3.551 seconds, max(|u|, |v|): 2.67e+00 3.73e+00 max(T): 3.03e+01, min(S): 2.81e+01
# [ Info: Iteration: 910, time: 18.958 days, wall_time: 3.506 seconds, max(|u|, |v|): 2.02e+00 4.10e+00 max(T): 3.04e+01, min(S): 2.80e+01
# [ Info: Iteration: 920, time: 19.167 days, wall_time: 3.693 seconds, max(|u|, |v|): 2.35e+00 3.33e+00 max(T): 3.03e+01, min(S): 2.81e+01
# [ Info: Iteration: 930, time: 19.375 days, wall_time: 3.704 seconds, max(|u|, |v|): 2.03e+00 3.87e+00 max(T): 3.03e+01, min(S): 2.81e+01
# [ Info: Iteration: 940, time: 19.583 days, wall_time: 3.847 seconds, max(|u|, |v|): 2.07e+00 4.35e+00 max(T): 3.03e+01, min(S): 2.81e+01
# [ Info: Iteration: 950, time: 19.792 days, wall_time: 3.810 seconds, max(|u|, |v|): 1.84e+00 3.48e+00 max(T): 3.03e+01, min(S): 2.81e+01
# [ Info: Iteration: 960, time: 20 days, wall_time: 3.974 seconds, max(|u|, |v|): 2.34e+00 2.76e+00 max(T): 3.03e+01, min(S): 2.80e+01
# [ Info: Iteration: 970, time: 20.208 days, wall_time: 3.842 seconds, max(|u|, |v|): 2.08e+00 3.47e+00 max(T): 3.03e+01, min(S): 2.81e+01
# [ Info: Iteration: 980, time: 20.417 days, wall_time: 3.790 seconds, max(|u|, |v|): 1.82e+00 4.83e+00 max(T): 3.03e+01, min(S): 2.81e+01
# [ Info: Iteration: 990, time: 20.625 days, wall_time: 3.939 seconds, max(|u|, |v|): 1.82e+00 4.25e+00 max(T): 3.04e+01, min(S): 2.80e+01
# [ Info: Iteration: 1000, time: 20.833 days, wall_time: 3.649 seconds, max(|u|, |v|): 2.16e+00 2.30e+00 max(T): 3.04e+01, min(S): 2.81e+01
# [ Info: Iteration: 1010, time: 21.042 days, wall_time: 3.726 seconds, max(|u|, |v|): 2.68e+00 2.59e+00 max(T): 3.04e+01, min(S): 2.81e+01
# [ Info: Iteration: 1020, time: 21.250 days, wall_time: 3.681 seconds, max(|u|, |v|): 1.43e+00 4.52e+00 max(T): 3.04e+01, min(S): 2.81e+01
# [ Info: Iteration: 1030, time: 21.458 days, wall_time: 3.586 seconds, max(|u|, |v|): 1.47e+00 4.19e+00 max(T): 3.04e+01, min(S): 2.81e+01
# [ Info: Iteration: 1040, time: 21.667 days, wall_time: 3.705 seconds, max(|u|, |v|): 1.69e+00 2.24e+00 max(T): 3.04e+01, min(S): 2.80e+01
# [ Info: Iteration: 1050, time: 21.875 days, wall_time: 3.847 seconds, max(|u|, |v|): 2.05e+00 2.52e+00 max(T): 3.04e+01, min(S): 2.81e+01
# [ Info: Iteration: 1060, time: 22.083 days, wall_time: 3.704 seconds, max(|u|, |v|): 2.31e+00 3.63e+00 max(T): 3.04e+01, min(S): 2.81e+01
# [ Info: Iteration: 1070, time: 22.292 days, wall_time: 3.612 seconds, max(|u|, |v|): 2.25e+00 4.00e+00 max(T): 3.04e+01, min(S): 2.81e+01
# [ Info: Iteration: 1080, time: 22.500 days, wall_time: 3.736 seconds, max(|u|, |v|): 1.83e+00 3.07e+00 max(T): 3.04e+01, min(S): 2.81e+01
# [ Info: Iteration: 1090, time: 22.708 days, wall_time: 3.846 seconds, max(|u|, |v|): 2.47e+00 3.13e+00 max(T): 3.05e+01, min(S): 2.81e+01
# [ Info: Iteration: 1100, time: 22.917 days, wall_time: 3.719 seconds, max(|u|, |v|): 2.20e+00 2.38e+00 max(T): 3.05e+01, min(S): 2.81e+01
# [ Info: Iteration: 1110, time: 23.125 days, wall_time: 3.747 seconds, max(|u|, |v|): 2.64e+00 4.20e+00 max(T): 3.06e+01, min(S): 2.81e+01
# [ Info: Iteration: 1120, time: 23.333 days, wall_time: 3.588 seconds, max(|u|, |v|): 2.32e+00 4.13e+00 max(T): 3.06e+01, min(S): 2.81e+01
# [ Info: Iteration: 1130, time: 23.542 days, wall_time: 3.583 seconds, max(|u|, |v|): 2.76e+00 4.04e+00 max(T): 3.06e+01, min(S): 2.82e+01
# [ Info: Iteration: 1140, time: 23.750 days, wall_time: 3.643 seconds, max(|u|, |v|): 2.51e+00 3.36e+00 max(T): 3.06e+01, min(S): 2.81e+01
# [ Info: Iteration: 1150, time: 23.958 days, wall_time: 3.696 seconds, max(|u|, |v|): 2.83e+00 4.12e+00 max(T): 3.07e+01, min(S): 2.82e+01
# [ Info: Iteration: 1160, time: 24.167 days, wall_time: 3.653 seconds, max(|u|, |v|): 2.56e+00 4.89e+00 max(T): 3.07e+01, min(S): 2.81e+01
# [ Info: Iteration: 1170, time: 24.375 days, wall_time: 3.766 seconds, max(|u|, |v|): 2.82e+00 3.96e+00 max(T): 3.07e+01, min(S): 2.81e+01
# [ Info: Iteration: 1180, time: 24.583 days, wall_time: 3.684 seconds, max(|u|, |v|): 2.37e+00 3.86e+00 max(T): 3.07e+01, min(S): 2.82e+01
# [ Info: Iteration: 1190, time: 24.792 days, wall_time: 3.732 seconds, max(|u|, |v|): 2.65e+00 3.67e+00 max(T): 3.07e+01, min(S): 2.81e+01
# [ Info: Iteration: 1200, time: 25 days, wall_time: 3.927 seconds, max(|u|, |v|): 2.09e+00 5.05e+00 max(T): 3.07e+01, min(S): 2.81e+01
# [ Info: Iteration: 1210, time: 25.208 days, wall_time: 3.789 seconds, max(|u|, |v|): 2.32e+00 3.91e+00 max(T): 3.08e+01, min(S): 2.82e+01
# [ Info: Iteration: 1220, time: 25.417 days, wall_time: 3.765 seconds, max(|u|, |v|): 1.88e+00 3.73e+00 max(T): 3.08e+01, min(S): 2.81e+01
# [ Info: Iteration: 1230, time: 25.625 days, wall_time: 3.596 seconds, max(|u|, |v|): 2.05e+00 2.82e+00 max(T): 3.08e+01, min(S): 2.82e+01
# [ Info: Iteration: 1240, time: 25.833 days, wall_time: 3.588 seconds, max(|u|, |v|): 2.08e+00 4.41e+00 max(T): 3.08e+01, min(S): 2.81e+01
# [ Info: Iteration: 1250, time: 26.042 days, wall_time: 3.590 seconds, max(|u|, |v|): 1.84e+00 4.05e+00 max(T): 3.08e+01, min(S): 2.81e+01
# [ Info: Iteration: 1260, time: 26.250 days, wall_time: 3.894 seconds, max(|u|, |v|): 1.84e+00 3.03e+00 max(T): 3.08e+01, min(S): 2.82e+01
# [ Info: Iteration: 1270, time: 26.458 days, wall_time: 3.583 seconds, max(|u|, |v|): 2.36e+00 2.48e+00 max(T): 3.08e+01, min(S): 2.81e+01
# [ Info: Iteration: 1280, time: 26.667 days, wall_time: 3.589 seconds, max(|u|, |v|): 2.24e+00 3.06e+00 max(T): 3.08e+01, min(S): 2.82e+01
# [ Info: Iteration: 1290, time: 26.875 days, wall_time: 3.677 seconds, max(|u|, |v|): 2.41e+00 4.34e+00 max(T): 3.08e+01, min(S): 2.82e+01
# [ Info: Iteration: 1300, time: 27.083 days, wall_time: 3.641 seconds, max(|u|, |v|): 2.28e+00 3.70e+00 max(T): 3.08e+01, min(S): 2.81e+01
# [ Info: Iteration: 1310, time: 27.292 days, wall_time: 3.575 seconds, max(|u|, |v|): 2.62e+00 2.22e+00 max(T): 3.08e+01, min(S): 2.82e+01
# [ Info: Iteration: 1320, time: 27.500 days, wall_time: 3.664 seconds, max(|u|, |v|): 2.69e+00 2.76e+00 max(T): 3.08e+01, min(S): 2.81e+01
# [ Info: Iteration: 1330, time: 27.708 days, wall_time: 3.725 seconds, max(|u|, |v|): 2.77e+00 4.20e+00 max(T): 3.07e+01, min(S): 2.82e+01
# [ Info: Iteration: 1340, time: 27.917 days, wall_time: 3.634 seconds, max(|u|, |v|): 2.71e+00 4.79e+00 max(T): 3.07e+01, min(S): 2.82e+01
# [ Info: Iteration: 1350, time: 28.125 days, wall_time: 3.688 seconds, max(|u|, |v|): 2.87e+00 3.29e+00 max(T): 3.07e+01, min(S): 2.81e+01
# [ Info: Iteration: 1360, time: 28.333 days, wall_time: 3.535 seconds, max(|u|, |v|): 2.82e+00 2.84e+00 max(T): 3.06e+01, min(S): 2.82e+01
# [ Info: Iteration: 1370, time: 28.542 days, wall_time: 3.597 seconds, max(|u|, |v|): 2.88e+00 4.46e+00 max(T): 3.06e+01, min(S): 2.82e+01
# [ Info: Iteration: 1380, time: 28.750 days, wall_time: 3.773 seconds, max(|u|, |v|): 2.89e+00 5.22e+00 max(T): 3.06e+01, min(S): 2.82e+01
# [ Info: Iteration: 1390, time: 28.958 days, wall_time: 3.666 seconds, max(|u|, |v|): 2.84e+00 3.48e+00 max(T): 3.05e+01, min(S): 2.82e+01
# [ Info: Iteration: 1400, time: 29.167 days, wall_time: 3.740 seconds, max(|u|, |v|): 2.88e+00 3.88e+00 max(T): 3.05e+01, min(S): 2.81e+01
# [ Info: Iteration: 1410, time: 29.375 days, wall_time: 3.648 seconds, max(|u|, |v|): 2.72e+00 3.48e+00 max(T): 3.04e+01, min(S): 2.82e+01
# [ Info: Iteration: 1420, time: 29.583 days, wall_time: 3.586 seconds, max(|u|, |v|): 2.77e+00 4.75e+00 max(T): 3.04e+01, min(S): 2.82e+01
# [ Info: Iteration: 1430, time: 29.792 days, wall_time: 3.583 seconds, max(|u|, |v|): 2.55e+00 3.81e+00 max(T): 3.04e+01, min(S): 2.82e+01
# [ Info: Simulation is stopping after running for 0 seconds.
# [ Info: Simulation time 30 days equals or exceeds stop time 30 days.
# [ Info: Iteration: 1440, time: 30 days, wall_time: 3.527 seconds, max(|u|, |v|): 2.62e+00 3.62e+00 max(T): 3.04e+01, min(S): 2.82e+01

# %% [markdown]
# ## Visualizing the results
#
# We can visualize the results using CairoMakie. We record a video of surface variables and fluxes.
# To load the data we can use Oceananigans' `FieldTimeSeries` object.

# %%
using JLD2
using Oceananigans
using Oceananigans.Grids: halo_size
using CairoMakie
using Statistics: mean

file  = jldopen("free_surface.jld2")
iters = keys(file["timeseries/t"])

Hx, Hy, _ = halo_size(η.grid)
T  = FieldTimeSeries("surface_fields.jld2", "T")
S  = FieldTimeSeries("surface_fields.jld2", "S")
s  = FieldTimeSeries("surface_fields.jld2", "s")

n  = Observable(1)
Tn = @lift(interior(T[$n], :, :, 1))
Sn = @lift(interior(S[$n], :, :, 1))
sn = @lift(interior(s[$n], :, :, 1))
ηn = @lift(file["timeseries/η/" * iters[$n]][Hx+1:end-Hx, Hy+1:end-Hy, 1])

fig = Figure(size = (1800, 800))
axT = Axis(fig[1, 1], title="Surface temperature ᵒC")
axS = Axis(fig[1, 2], title="Surface salinity psu")
axs = Axis(fig[2, 1], title="Surface speed ms⁻¹")
axη = Axis(fig[2, 2], title="Sea surface height m")

λ, φ, z = nodes(T[1])

hmT = heatmap!(axT, Tn, colormap=:magma,  colorrange=(-1, 30))
hmS = heatmap!(axS, Sn, colormap=:haline, colorrange=(25, 40))
hms = heatmap!(axs, sn, colormap=:deep,   colorrange=( 0, 0.8))
hmη = heatmap!(axη, ηn, colormap=:bwr,    colorrange=(-1, 1))

CairoMakie.record(fig, "surface_fields.gif", 1:length(T.times); framerate=5) do i
    @info "doing $i of $(length(T.times))"
    n[] = i
end

# %%
display(MIME"image/png"(), read(open("surface_fields.gif")))

# %% [markdown]
# let's also visualize the surface fluxes that force the model

# %%
Q  = FieldTimeSeries("surface_fluxes.jld2", "Q")
τx = FieldTimeSeries("surface_fluxes.jld2", "τx")
τy = FieldTimeSeries("surface_fluxes.jld2", "τy")
PE = FieldTimeSeries("surface_fluxes.jld2", "PE")

Qn  = @lift(interior(Q[$n],  :, :, 1))
τxn = @lift(interior(τx[$n], :, :, 1))
τyn = @lift(interior(τy[$n], :, :, 1))
PEn = @lift(interior(PE[$n], :, :, 1))

fig  = Figure(size = (1800, 800))
axQ  = Axis(fig[1, 1], title="Net heat flux Wm⁻²")
axPE = Axis(fig[1, 2], title="Net salt flux psu m s⁻¹")
axτx = Axis(fig[2, 1], title="Zonal wind stress Nm⁻²")
axτy = Axis(fig[2, 2], title="Meridional wind stress Nm⁻²")

hmQ  = heatmap!(axQ,  Qn,  colormap=:magma,   colorrange=(-800,  800))
hmPE = heatmap!(axPE, PEn, colormap=:haline,  colorrange=(-1e-5, 5e-5))
hmτx = heatmap!(axτx, τxn, colormap=:balance, colorrange=(-5e-4, 5e-4))
hmτy = heatmap!(axτy, τyn, colormap=:balance, colorrange=(-5e-4, 5e-4))

CairoMakie.record(fig, "surface_fluxes.mp4", 1:length(Q.times); framerate=5) do i
    @info "doing $i of $(length(Q.times))"
    n[] = i
end

# %% [markdown]
# Let's visualize the internal structure of temperature and salinity

# %%
x, y, z = nodes(ocean.model.tracers.T)

fig = Figure(size = (1200, 400))
axT = Axis(fig[1, 1], title="Internal temperature structure ᵒC")
axS = Axis(fig[1, 2], title="Internal salinity structure psu")

contourf!(axT, 1:128, z, interior(mean(ocean.model.tracers.T, dims=1), 1, :, :), colormap=:magma)
contourf!(axS, 1:128, z, interior(mean(ocean.model.tracers.S, dims=1), 1, :, :), colormap=:haline)
display(fig)

# %% [markdown]
# # Running a high-resolution simulation
#
# What are the steps to modify the above script to run an eddying (quarter degree) simulation?
